# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn
seaborn.set()

# %%
with open('../input/Accidents0515.csv', 'r') as f:
    df = pd.read_csv(f)

# %%
acc.drop(['Accident_Index'],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-dfb24c7759dc> in <module>()
# ----> 1 acc.drop(['Accident_Index'],axis = 1)
#
# /Users/zhangtao/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# /Users/zhangtao/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# -> 3051                                  labels[mask])
# ...

# %%
acc.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-fb9b09b4024b> in <module>()
# ----> 1 acc.columns()
#
# TypeError: 'Index' object is not callable

# %%
acc['Accident_Severity'].unique()
# Out:
# array([2, 3, 1])

# %%
plt.scatter(accident.Longitude,accident.Latitude,c = accident.Police_Force)

# %% [markdown]
# Diiffrent Police_Force distribution.

# %%
plt.scatter(accident.Longitude,accident.Latitude,c = accident.Accident_Severity)

# %%
#The accident Severity is chaotic and random, we need to analyze it
accident.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-f4a3d5a67711> in <module>()
#       1 #The accident Severity is chaotic and random, we need to analyze it
# ----> 2 accident.columns()
#
# TypeError: 'Index' object is not callable

# %%
accident_count = accident.groupby(accident.Accident_Severity)['Accident_Index'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-13fd6efc2953> in <module>()
# ----> 1 accident_count = accident.groupby(accident.Accident_Severity)['Accident_Index'].count()
#
# /Users/zhangtao/anaconda/lib/python2.7/site-packages/pandas/core/base.pyc in __getitem__(self, key)
#     341         else:
#     342             if key not in self.obj:
# --> 343                 raise KeyError("Column not found: %s" % key)
#     344             return self._gotitem(key, ndim=1)
#     345
#
# KeyError: 'Column not found: Accident_Index'

# %%
accident_count.head()
# Out:
#                    ﻿Accident_Index  Location_Easting_OSGR  \
# Accident_Severity
# 1                            22998                  22998
# 2                           242080                 242059
# 3                          1515575                1515458
#
#                    Location_Northing_OSGR  Longitude  Latitude  Police_Force  \
# Accident_Severity
# 1                                   22998      22998     22998         22998
# 2                                  242059     242059    242059        242080
# 3                                 1515458    1515458   1515458       1515575
#
#                    Number_of_Vehicles  Number_of_Casualties     Date  \
# Accident_Severity
# 1                               22998                 22998    22998
# 2                              242080                242080   242080
# 3                             1515575               1515575  1515575
#
#                    Day_of_Week            ...              \
# ...
